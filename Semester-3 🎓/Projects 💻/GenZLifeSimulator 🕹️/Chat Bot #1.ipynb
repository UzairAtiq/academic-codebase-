# %%
# Name : Muhammad Uzair Attiq 
# Enroll : 01-136242-029
# Assignment # 1 Programming for Artificial Intelligence

# %%
#Greeting the user and getting his info
def greetUser() : 

  print("👋 Yo bestie, welcome to the Gen Z Life Chatbot 💅")
  print("I’m your digital bestie — part chaos, part wisdom, all vibes 💻✨")
  print("Spill the tea, ask the questions, or just vibe with me 💬")
  print("Type anything and let’s make this convo main-character worthy 💫")

  name = input("Hey bestie! Drop your name: ")
  age = int(input("What's your age bestie? "))

  #Storing in dictionary
  user = {"name" : name , "age" : age}

  return user

# %%
responses = {
    "hello": "Yo yo yo! What's good? ✨",
    "what's up": "Just chillin' like a villain fr 😎",
    "good morning": "Morning bestie! Ready to slay today? ☀️",
    "good night": "Sleep tight, don't let the bed bugs bite! 🌙",
    "thank you": "No cap, you're welcome queen/king! 👑",
    "sorry": "It's giving main character energy, we move! 💅",
    "yes": "Periodt! That's the tea! ☕",
    "no": "Nah bestie, that ain't it chief 🙅‍♀️",
    "okay": "Bet! Say less! 🤝",
    "cool": "That's lowkey fire ngl 🔥",
    "awesome": "Stop it's giving iconic energy! ✨",
    "nice": "Chef's kiss! *muah* 💋",
    "wow": "I'm deceased! This is sending me! 💀",
    "omg": "I literally can't even right now! 😭",
    "lol": "Bestie you're too funny! I'm wheezing! 😂",
    "help": "Bestie I got you! What's the sitch? 🤗",
    "tired": "Mood! Big mood! Same energy! 😴",
    "hungry": "Time for some snacks! We love a foodie moment! 🍕",
    "bored": "Let's find some chaos to get into! 😈",
    "excited": "The hype is real! We're living for this! 🎉",
    "sad": "Sending virtual hugs bestie! You got this! 🫂",
    "happy": "Living your best life! We love to see it! 😊",
    "angry": "Breathe bestie! Don't let them steal your peace! 😤",
    "confused": "Bestie same! That's giving confusing energy! 🤔",
    "surprised": "Plot twist! I did not see that coming! 😱",
    "love you": "Aw bestie! Love you to the moon and back! 💕",
    "miss you": "Stop I'm soft! Miss you more! Come back! 🥺",
    "congratulations": "Bestie you ATE and left no crumbs! So proud! 🎊",
    "good luck": "You're about to serve! Go get 'em tiger! 🍀",
    "see you later": "Catch you on the flip side bestie! Stay iconic! 👋"
}

# %%
#Bye function 
def endChat() : 
  print("Catch you later bestie! Chat's over! ✨")

# %%
#Getting Chatbot response 
def getResponse(res, userName) :
  print(f"{userName}: {res}")
  if res in responses :
    print(f"Chatbot: {responses[res]}")
  else :
    print("Chatbot: Bestie I'm lowkey confused... that's not in my vocab! 💭")

# %%
#Display Stats
def showStats(energy, points, mood) :
  print(f"⚡ Energy Level: {energy} (we're vibing!)")
  print(f"🏆 Points Earned: {points} (you're slaying!)")
  print(f"😊 Current Mood: {mood} (the energy is real!)")

# %%
#Update stats function 
def updateStats(activity, energy, points, mood) :
  if activity == "study" : #Updating according to activity chosen
    energy -= 20
    points += 10
    mood = "🙄" 
  elif activity == "eat" :
    energy += 15 
    mood = "☺️"
  elif activity in ["play games" , "play" , "games"] :
    energy -= 1
    points += 5 
    mood = "😎"
  elif activity == "sleep" :
    energy = 100
    mood = "😴"
  else : 
    print("Bestie that's not a vibe! Pick something else! 😅")
  return energy, points, mood

# %%
  #End Game function 
def endGame(energy, points, mood) : # Displaying Stats
    print("🎯 Final Stats - You absolutely ATE bestie! 🎯")
    print(f"⚡ Final Energy: {energy} (battery levels!)")
    print(f"🏆 Total Points: {points} (you're iconic!)")
    print(f"😊 End Mood: {mood} (what a journey!)")
    print("Thanks for playing! You're the main character! ✨")
    print()

# %%
import requests
import random

def uniqueFeature() : 
  try:
    url = "https://yurippe.vercel.app/api/quotes?show=code geass,rose of versailles,violet evergarden"
    response = requests.get(url)
    data = response.json()
    
    # Check if we got quotes data
    if data and len(data) > 0:
      # Pick a random quote from the returned data
      randomQuote = random.choice(data)
      
      print("🌟 MYSTERY BOX UNLOCKED! Here's your anime wisdom bestie! 🌟")
      
      # Check different possible key names for quote and character
      if 'quote' in randomQuote:
        quoteText = randomQuote['quote']
      elif 'text' in randomQuote:
        quoteText = randomQuote['text']
      else:
        quoteText = str(randomQuote)  
        
      if 'name' in randomQuote:
        characterName = randomQuote['name']
      elif 'character' in randomQuote:
        characterName = randomQuote['character']
      elif 'author' in randomQuote:
        characterName = randomQuote['author']
      else:
        characterName = "Unknown Character"
      
      print(f"💬 Quote: \"{quoteText}\"")
      print(f"👤 Character: {characterName}")
      print("That's some main character energy right there! ✨")
    else:
      print("🌟 MYSTERY BOX: No quotes found bestie! 😅")
      print("Here's some backup Gen Z wisdom:")
      print("💬 \"You're not just the main character, you're the whole anime! ✨\"")
      print("👤 Character: You, the icon!")
      
  except Exception as e:
    print("🌟 MYSTERY BOX: Connection is being sus bestie! 📶")
    print("But here's some Gen Z wisdom for you:")
    print("💬 \"Plot armor is real when you believe in yourself! 💪✨\"")
    print("👤 Character: Your inner main character!")
    
uniqueFeature()
# Out:
# 🌟 MYSTERY BOX UNLOCKED! Here's your anime wisdom bestie! 🌟
# 💬 Quote: "Why can't I hear the firing of our cannons? Fire, keep firing, seize the Bastille!"
# 👤 Character: Oscar Jarjayes
# That's some main character energy right there! ✨

# %%
#Main game function 
def mainGame() : 
  energy = 0
  points = 0
  mood = "😁"

  print("✨ WELCOME TO THE GEN Z LIFE SIMULATOR ✨")
  print("What's the vibe today bestie? Choose your main character moment:")
  print()
  print("📚 Study → -20 Energy | +10 Points | Mood: ‘productive grind mode’")
  print("🍕 Eat → +15 Energy | Mood: ‘food coma incoming’")
  print("🎮 Play Games → -10 Energy | +5 Points | Mood: ‘gamer vibes activated’")
  print("😴 Sleep → Energy = 100 | Mood: ‘well rested queen ✨’")
  print("🌸 Anime Quote Box → ??? | Mood: ‘wisdom from another world…’")
  print("💪Wanna flex your stats? Type ‘show stats’ 🔥")
  print("🚪 Exit → Peace out bestie 👋")

  while True : # Loop for playing the game 
    activity = input("What do you want to do?").lower()
    print()
    if activity == "study" :
      print("Time to hit the books bestie! 📚 Brain gains incoming!")
      energy, points, mood = updateStats(activity, energy, points, mood)
    elif activity == "eat" :
      print("Snack time! 🍕 Fueling up like the icon you are!")
      energy, points, mood = updateStats(activity, energy, points, mood)
    elif activity in ["play games" , "play" , "game"]:
      print("Gaming mode activated! 🎮 Solo Leveling vibes fr!")
      energy, points, mood = updateStats(activity, energy, points, mood)
    elif activity == "sleep" :
      print("Beauty sleep time! 😴 Recharging those main character batteries!")
      energy, points, mood = updateStats(activity, energy, points, mood)
    elif activity == "anime" : 
      uniqueFeature()
    elif activity == "stats" :
      showStats(energy, points, mood)
    elif activity == "exit" :
      print("Peace out bestie! 👋 Thanks for the vibes!")
      endGame(energy, points, mood)
      break
    else: 
      print("Sorry besite😔 That's not an option💔 Choose One that is available😊")
      break

# %%
user = greetUser() #Greeting the user

while True : # Loop to check what the user has chosen i.e chatting , game or exit
    userResponse = input("Bestie, what's the vibe today? Tell me what you wanna do: ").lower()
    if userResponse == "bye" :
        print(f"{user['name']}: {userResponse}")
        endChat()
        break
    elif userResponse == "play" :
        print(f"{user['name']}: {userResponse}")
        answer = input("Ooo want to play GenZ Life Simulator with me? (yes/no)").lower()
        if answer == "yes" :
            print(f"{user['name']}: {answer}")
            mainGame()
        else:
            print(f"{user['name']}: {answer}")
            print("Chatbot: Maybe next time bestie! Let's keep chatting! 💬")
    else :
        getResponse(userResponse, user['name'])
# Out:
# 👋 Yo bestie, welcome to the Gen Z Life Chatbot 💅
# I’m your digital bestie — part chaos, part wisdom, all vibes 💻✨
# Spill the tea, ask the questions, or just vibe with me 💬
# Type anything and let’s make this convo main-character worthy 💫
